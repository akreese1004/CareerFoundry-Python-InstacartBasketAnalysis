# %% [markdown]
# # 4.7 - Deriving New Variables

# %%
# Import libraries

import pandas as pd
import numpy as np
import os

# %%
ords_prods_merge = pd.read_pickle (r'/Users/aaronreese/Desktop/Instacart Basket Analysis/2. Data/Prepared Data/orders_products_merged.pkl')

# %%
df = ords_prods_merge[:1000000]

# %%
df.shape
# Out:
# (1000000, 15)

# %% [markdown]
# ## If Functions

# %%
def price_label(row):

  if row['prices'] <= 5:
    return 'Low-range product'
  elif (row['prices'] > 5) and (row['prices'] <= 15):
    return 'Mid-range product'
  elif row['prices'] > 15:
    return 'High range'
  else: return 'Not enough data'

# %% [markdown]
# ## Apply price_range

# %%
df['price_range'] = df.apply(price_label, axis=1)
# Out:
# /var/folders/xg/9wtmprmn2396bpwzl7d3cj9c0000gn/T/ipykernel_20720/2848743372.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price_range'] = df.apply(price_label, axis=1)

# %%
df['price_range'].value_counts(dropna = False)
# Out:
# Mid-range product    756450
# Low-range product    243550
# Name: price_range, dtype: int64

# %%
df['prices'].max()
# Out:
# 14.8

# %% [markdown]
# ## df.loc()

# %%
df.loc[df['prices'] > 15, 'price_range_loc'] = 'High-range product'
# Out:
# /var/folders/xg/9wtmprmn2396bpwzl7d3cj9c0000gn/T/ipykernel_20720/1169838859.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[df['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
df.loc[(df['prices'] <= 15) & (df['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
df.loc[df['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
df['price_range_loc'].value_counts(dropna = False)
# Out:
# Mid-range product    756450
# Low-range product    243550
# Name: price_range_loc, dtype: int64

# %% [markdown]
# ## loc() on Entire Dataframe

# %%
ords_prods_merge.loc[ords_prods_merge['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
ords_prods_merge.loc[(ords_prods_merge['prices'] <= 15) & (ords_prods_merge['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
ords_prods_merge.loc[ords_prods_merge['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
ords_prods_merge['price_range_loc'].value_counts(dropna = False)
# Out:
# Mid-range product     21890146
# Low-range product     10126384
# High-range product      417682
# Name: price_range_loc, dtype: int64

# %% [markdown]
# ## For Loops

# %%
ords_prods_merge['orders_day_of_week'].value_counts(dropna = False)
# Out:
# 0    6209632
# 1    5665830
# 6    4500246
# 2    4217766
# 5    4209449
# 3    3844096
# 4    3787193
# Name: orders_day_of_week, dtype: int64

# %%
result = []

for value in ords_prods_merge["orders_day_of_week"]: 
    if value == 0:
        result.append("Busiest day")
    elif value == 4:
        result.append("Least busy")
    else: 
        result.append("Regularly busy")

# %%
result
# Out:
# ['Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
# ...

# %%
ords_prods_merge['busiest_day'] = result

# %%
ords_prods_merge['busiest_day'].value_counts(dropna = False)
# Out:
# Regularly busy    22437387
# Busiest day        6209632
# Least busy         3787193
# Name: busiest_day, dtype: int64

# %% [markdown]
# ## Task

# %% [markdown]
# ### Question 2

# %%
result = []

for value in ords_prods_merge["orders_day_of_week"]: 
    if value == (0 or 1):
        result.append("Busiest days")
    elif value == (4 or 3):
        result.append("Slowest days")
    else: 
        result.append("Regularly busy")

# %%
ords_prods_merge['busiest_days'] = result

# %% [markdown]
# ### Question 3

# %%
ords_prods_merge['busiest_days'].value_counts(dropna = False)
# Out:
# Regularly busy    22981189
# Busiest days       5665830
# Slowest days       3787193
# Name: busiest_days, dtype: int64

# %% [markdown]
# There are significantly more of the busiest days vs the slowest days.

# %% [markdown]
# ### Question 4

# %%
ords_prods_merge['order_hour_of_day'].value_counts(dropna = False)
# Out:
# 10    2764390
# 11    2738585
# 14    2691563
# 15    2664522
# 13    2663272
# 12    2620800
# 16    2537469
# 9     2456661
# 17    2089452
# 8     1719952
# 18    1637922
# 19    1259382
# 20     977017
# 7      891928
# 21     796362
# 22     634737
# 23     402612
# 6      290770
# 0      218942
# 1      115786
# 5       88057
# 2       69431
# 4       53283
# 3       51317
# Name: order_hour_of_day, dtype: int64

# %%
result = []

for value in ords_prods_merge["order_hour_of_day"]: 
    if value == (10 or 11 or 14 or 15 or 13 or 1 or 16 or 9):
        result.append("Most orders")
    elif value == (17 or 8 or 18 or 19 or 20 or 7 or 21 or 22):
        result.append("Average orders")
    else: 
        result.append("Fewest orders")

# %%
ords_prods_merge['busiest_period_of_day'] = result

# %% [markdown]
# ### Question 5

# %%
ords_prods_merge['busiest_period_of_day'].value_counts(dropna = False)
# Out:
# Fewest orders     27580370
# Most orders        2764390
# Average orders     2089452
# Name: busiest_period_of_day, dtype: int64

# %% [markdown]
# ### Export

# %%
ords_prods_merge.to_pickle('/Users/aaronreese/Desktop/Instacart Basket Analysis/2. Data/Prepared Data/4-7_ords_prods_merge.pkl')
