# %% [markdown]
# # 4.8 Task

# %%
import pandas as pd
import numpy as np
import os

# %%
ords_prods_merge = pd.read_pickle (r'/Users/aaronreese/Desktop/Instacart Basket Analysis/2. Data/Prepared Data/4-7_ords_prods_merge.pkl')

# %%
ords_prods_merge.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0_x  order_id  user_id eval_set  order_number  \
# 0             0             0   2539329        1    prior             1
# 1             1             1   2398795        1    prior             2
# 2             2             2    473747        1    prior             3
# 3             3             3   2254736        1    prior             4
# 4             4             4    431534        1    prior             5
#
#    orders_day_of_week  order_hour_of_day  days_since_prior_order  product_id  \
# 0                   2                  8                     NaN         196
# 1                   3                  7                    15.0         196
# 2                   3                 12                    21.0         196
# 3                   4                  7                    29.0         196
# 4                   4                 15                    28.0         196
#
# ...

# %%
ords_prods_merge.shape
# Out:
# (32434212, 22)

# %% [markdown]
# ### Question 2

# %%
ords_prods_merge.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                15.457687
# 2                17.277920
# 3                17.179756
# 4                17.811403
# 5                15.213779
# 6                16.439806
# 7                17.225773
# 8                15.340520
# 9                15.895474
# 10               20.197148
# 11               16.170828
# 12               15.887622
# 13               16.583304
# 14               16.757377
# 15               16.165037
# 16               17.663250
# 17               15.694469
# 18               19.310397
# 19               17.177343
# 20               16.473447
# 21               22.902379

# %% [markdown]
# ### Question 3

# %% [markdown]
# Averages for whole dataframe are overall lower than the subset's averages.  This is due to more data being processed causing the averages to be lower than just a subset of the data.

# %% [markdown]
# ### Question 4

# %%
ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)

# %%
ords_prods_merge.head(15)
# Out:
#     Unnamed: 0.1  Unnamed: 0_x  order_id  user_id eval_set  order_number  \
# 0              0             0   2539329        1    prior             1
# 1              1             1   2398795        1    prior             2
# 2              2             2    473747        1    prior             3
# 3              3             3   2254736        1    prior             4
# 4              4             4    431534        1    prior             5
# 5              5             5   3367565        1    prior             6
# 6              6             6    550135        1    prior             7
# 7              7             7   3108588        1    prior             8
# 8              8             8   2295261        1    prior             9
# 9              9             9   2550362        1    prior            10
# 10           144           144   2968173       15    prior            15
# 11           146           146   1870022       15    prior            17
# ...

# %%
ords_prods_merge.head(100)
# Out:
#     Unnamed: 0.1  Unnamed: 0_x  order_id  user_id eval_set  order_number  \
# 0              0             0   2539329        1    prior             1
# 1              1             1   2398795        1    prior             2
# 2              2             2    473747        1    prior             3
# 3              3             3   2254736        1    prior             4
# 4              4             4    431534        1    prior             5
# ..           ...           ...       ...      ...      ...           ...
# 95          5895          5895   3226575      360    prior             1
# 96          6137          6137   1469869      377    prior             3
# 97          6259          6259   1927023      387    prior             2
# 98          6740          6740    858092      420    prior             4
# 99          6741          6741    119314      420    prior             5
#
#     orders_day_of_week  order_hour_of_day  days_since_prior_order  product_id  \
# ...

# %%
pd.options.display.max_rows = None

# %%
ords_prods_merge.head(100)
# Out:
#     Unnamed: 0.1  Unnamed: 0_x  order_id  user_id eval_set  order_number  \
# 0              0             0   2539329        1    prior             1
# 1              1             1   2398795        1    prior             2
# 2              2             2    473747        1    prior             3
# 3              3             3   2254736        1    prior             4
# 4              4             4    431534        1    prior             5
# 5              5             5   3367565        1    prior             6
# 6              6             6    550135        1    prior             7
# 7              7             7   3108588        1    prior             8
# 8              8             8   2295261        1    prior             9
# 9              9             9   2550362        1    prior            10
# 10           144           144   2968173       15    prior            15
# 11           146           146   1870022       15    prior            17
# ...

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'
ords_prods_merge.loc[(ords_prods_merge['max_order'] <= 40) & (ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'
ords_prods_merge.loc[ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
ords_prods_merge['loyalty_flag'].value_counts(dropna = False)
# Out:
# Regular customer    15891077
# Loyal customer      10293737
# New customer         6249398
# Name: loyalty_flag, dtype: int64

# %% [markdown]
# ### Question 5

# %%
ords_prods_merge[['user_id', 'loyalty_flag', 'prices']].head(100)
# Out:
#     user_id      loyalty_flag  prices
# 0         1      New customer     9.0
# 1         1      New customer     9.0
# 2         1      New customer     9.0
# 3         1      New customer     9.0
# 4         1      New customer     9.0
# 5         1      New customer     9.0
# 6         1      New customer     9.0
# 7         1      New customer     9.0
# 8         1      New customer     9.0
# 9         1      New customer     9.0
# 10       15  Regular customer     9.0
# 11       15  Regular customer     9.0
# 12       15  Regular customer     9.0
# 13       15  Regular customer     9.0
# 14       15  Regular customer     9.0
# 15       19      New customer     9.0
# 16       19      New customer     9.0
# 17       19      New customer     9.0
# 18       21  Regular customer     9.0
# 19       31  Regular customer     9.0
# 20       31  Regular customer     9.0
# 21       43  Regular customer     9.0
# 22       43  Regular customer     9.0
# 23       52  Regular customer     9.0
# ...

# %% [markdown]
# ### Question 6

# %%
ords_prods_merge['spender'] = ords_prods_merge.groupby(['user_id'])['prices'].transform(np.max)

# %%
ords_prods_merge.loc[ords_prods_merge['spender'] < 10, 'spending_flag'] = 'Low spender'
ords_prods_merge.loc[ords_prods_merge['spender'] >= 10, 'spending_flag'] = 'High spender'

# %%
ords_prods_merge['spending_flag'].value_counts(dropna = False)
# Out:
# High spender    32402635
# Low spender        31577
# Name: spending_flag, dtype: int64

# %% [markdown]
# ### Question 7

# %%
ords_prods_merge.groupby('department_id').agg({'days_since_prior_order': ['median']})
# Out:
#               days_since_prior_order
#                               median
# department_id
# 1                                8.0
# 2                                7.0
# 3                                8.0
# 4                                7.0
# 5                                7.0
# 6                                8.0
# 7                                8.0
# 8                                9.0
# 9                                8.0
# 10                               7.0
# 11                               8.0
# 12                               8.0
# 13                               8.0
# 14                               8.0
# 15                               8.0
# 16                               8.0
# 17                               8.0
# 18                               7.0
# 19                               8.0
# 20                               8.0
# 21                               7.0

# %%
ords_prods_merge['order_frequency'] = ords_prods_merge.groupby(['user_id'])['days_since_prior_order'].transform(np.max)

# %%
ords_prods_merge.loc[ords_prods_merge['order_frequency'] > 20, 'frequency_flag'] = 'Non-frequent customer'
ords_prods_merge.loc[(ords_prods_merge['order_frequency'] > 10) & (ords_prods_merge['order_frequency'] <= 20), 'frequency_flag'] = 'Regular customer'
ords_prods_merge.loc[ords_prods_merge['order_frequency'] <= 10, 'frequency_flag'] = 'Frequent customer'

# %%
ords_prods_merge['frequency_flag'].value_counts(dropna = False)
# Out:
# Non-frequent customer    24509620
# Regular customer          6539471
# Frequent customer         1385121
# Name: frequency_flag, dtype: int64

# %% [markdown]
# ### Export

# %%
ords_prods_merge.drop (['Unnamed: 0.1','Unnamed: 0_x','Unnamed: 0_y'], axis = 1)

# %%
ords_prods_merge.to_pickle('/Users/aaronreese/Desktop/Instacart Basket Analysis/2. Data/Prepared Data/4-8_ords_prods_merge.pkl')
